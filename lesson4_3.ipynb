# %%
import csv

from pprint import pprint
with open(file='abc.csv',encoding='utf-8') as file:
    reader = csv.DictReader(file)
    home = list(reader)

pprint(home)
# Out:
# [{'傳真': '9898022',
#   '地址': '宜蘭縣三星鄉大隱村三星路2段103號',
#   '機構名稱': '財團法人天主教靈醫會附設宜蘭縣私立聖嘉民老人長期照顧中心(養護型)',
#   '負責人': '呂若瑟',
#   '電話': '9898806',
#   '\ufeff編號': '1'},
#  {'傳真': '9894086',
#   '地址': '宜蘭縣三星鄉大坑路15之4號',
#   '機構名稱': '宜蘭縣私立安親老人養護院',
#   '負責人': '柳淑真',
#   '電話': '9894085',
#   '\ufeff編號': '2'},
#  {'傳真': '9500178',
#   '地址': '宜蘭縣五結鄉季水路15巷46號',
#   '機構名稱': '財團法人宜蘭縣私立親水園養護之家',
#   '負責人': '陳玉雲',
#   '電話': '9500180',
#   '\ufeff編號': '3'},
#  {'傳真': '9606070',
#   '地址': '宜蘭縣五結鄉親河路2段58巷78號',
#   '機構名稱': '財團法人宜蘭縣私立慈愛養護院',
#   '負責人': '林哲弘',
#   '電話': '9606000',
#   '\ufeff編號': '4'},
#  {'傳真': '9650903',
#   '地址': '宜蘭縣五結鄉中正路三段21號2-6樓',
#   '機構名稱': '財團法人宜蘭縣私立力麗樂活老人長期照顧中心(養護型)',
#   '負責人': '郭濟安',
#   '電話': '9650736',
#   '\ufeff編號': '5'},
#  {'傳真': '',
#   '地址': '宜蘭縣五結鄉中正路三段146巷7號',
#   '機構名稱': '宜蘭縣私立桑榆老人長期照顧中心(養護型)',
#   '負責人': '陳玟均',
#   '電話': '9659696',
#   '\ufeff編號': '6'},
#  {'傳真': '9588385',
#   '地址': '宜蘭縣冬山鄉清溝村永安路389號',
#   '機構名稱': '宜蘭縣私立杏林老人長期照顧中心(養護型)',
#   '負責人': '江柏村',
# ...
